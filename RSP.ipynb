# %% [markdown]
# <a href="https://colab.research.google.com/github/sratnaparkhi/tensorflow/blob/main/RSP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import zipfile

import os
os.environ['KAGGLE_USERNAME'] = "sagarratnaparkhi" # username from the json file
os.environ['KAGGLE_KEY'] = "4d1ce255754cadb3e41675d34e05ad34" # key from the json file
#!kaggle datasets download -d iarunava/happy-house-dataset # api copied from kaggle

# !kaggle datasets download -d drgfreeman/rockpaperscissors


local_zip = '/content/rockpaperscissors.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/content/rockpaperscissors')
zip_ref.close()
# Out:
# rockpaperscissors.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
rock_dir = os.path.join('/content/rockpaperscissors/rock')
paper_dir = os.path.join('/content/rockpaperscissors/paper')
scissors_dir = os.path.join('/content/rockpaperscissors/scissors')

print('total training rock images:', len(os.listdir(rock_dir)))
print('total training paper images:', len(os.listdir(paper_dir)))
print('total training scissors images:', len(os.listdir(scissors_dir)))
# Out:
# total training rock images: 726
# total training paper images: 712
# total training scissors images: 750

# %%
rock_files = os.listdir(rock_dir)
print(rock_files[:10])

paper_files = os.listdir(paper_dir)
print(paper_files[:10])

scissors_files = os.listdir(scissors_dir)
print(scissors_files[:10])
# Out:
# ['IcqtnpGHgStAPMXM.png', 'N3pHY9fO1y0jdeVu.png', 'NuJjhPSItSWUuMOk.png', 'foxUXc8WPRDAd6LM.png', 'BOswKcczxw8dC4kY.png', '8EjcPHxZBpTtX8bM.png', 'H2lQHx5y3oy8mLSL.png', 'DxBmPozYTIgMWX7j.png', '7NqXwATGidLt6kZY.png', 'oYofHCDonUnJKd0C.png']
# ['Ht08RX3DQCSdl9Sy.png', '8vCpdCGSnX8CopJJ.png', 'Mv6oOH192gse3oZA.png', '2DQbLQfHlfrcATqi.png', 'hWVwQVI74lc5zgyK.png', 'W4QtOYoG8ThbcmsY.png', 'MLrUGD1graoSw2c5.png', '3sKeYzYsjbWQVhc4.png', 'B3dlyiRDulDJWOsW.png', 'zXY93m62vUNIH4a0.png']
# ['FZTB5QPwvq7b9xok.png', 'eJ9GdFE4kzE0t5zh.png', 'nukdu4gV8vol1FY9.png', 'nIwv11WKj5Ch85mv.png', 'jMVjrTQfvJ0xLTOt.png', 'e7wuzMq70FDcvaFr.png', 'kC1AoCFrvaMKlTDk.png', 'gK1XEsUjwJ5gDOSz.png', 'wuoizA09gXbcCZ5a.png', '6weMqPPWdXLD7lNy.png']

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

pic_index = 2

next_rock = [os.path.join(rock_dir, fname)
                for fname in rock_files[pic_index-2:pic_index]]
next_paper = [os.path.join(paper_dir, fname)
                for fname in paper_files[pic_index-2:pic_index]]
next_scissors = [os.path.join(scissors_dir, fname)
                for fname in scissors_files[pic_index-2:pic_index]]

for i, img_path in enumerate(next_rock+next_paper+next_scissors):
  #print(img_path)
  img = mpimg.imread(img_path)
  plt.imshow(img)
  plt.axis('Off')
  plt.show()
